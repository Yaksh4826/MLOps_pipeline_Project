# %%
import os
import tensorflow_data_validation as tfdv
from tfx.types import artifact_utils
from tfx.types.standard_artifacts import Statistics, Schema, ExampleAnomalies

# %%
PIPELINE_OUTPUT = "outputs/obesity_data_validation_pipeline"

# ---------------------------------------------------------
# STEP 1 — ExampleGen: Show URIs
# ---------------------------------------------------------

example_gen_path = os.path.join(PIPELINE_OUTPUT, "CsvExampleGen")
print("ExampleGen Output Path:", example_gen_path)

train_uri = os.path.join(example_gen_path, "examples/1/train")
eval_uri = os.path.join(example_gen_path, "examples/1/eval")

print("Train URI:", train_uri)
print("Eval URI:", eval_uri)
# Out:
# ExampleGen Output Path: outputs/obesity_data_validation_pipeline/CsvExampleGen
# Train URI: outputs/obesity_data_validation_pipeline/CsvExampleGen/examples/1/train
# Eval URI: outputs/obesity_data_validation_pipeline/CsvExampleGen/examples/1/eval

# %%
stats_path = os.path.join(PIPELINE_OUTPUT, "StatisticsGen/statistics/6")
stats = tfdv.load_statistics(stats_path)

tfdv.visualize_statistics(stats)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_4327/2088400253.py in <module>
#       1 stats_path = os.path.join(PIPELINE_OUTPUT, "StatisticsGen/statistics/6")
# ----> 2 stats = tfdv.load_statistics(stats_path)
#       3
#       4 tfdv.visualize_statistics(stats)
#
# ~/anaconda3/envs/tfx-env/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_util.py in load_statistics(input_path)
#     360   """
#     361   if not tf.io.gfile.exists(input_path):
# --> 362     raise IOError('Invalid input path {}.'.format(input_path))
#     363   try:
#     364     return load_stats_tfrecord(input_path)
#
# OSError: Invalid input path outputs/obesity_data_validation_pipeline/StatisticsGen/statistics/6.
